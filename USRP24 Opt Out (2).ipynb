# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.optimize as so

data = np.genfromtxt('data.txt', names=True, dtype=None)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Data Set with Y Standard Deviation')
plt.errorbar(data['x'], data['y'], data['y_std'], color = 'red', linestyle='None', marker='^')

plt.show()
# Out:
# [0.8243 1.1299 0.8912 0.7326 0.7115 1.0423 0.7381 1.2995 1.2154 0.6087
#  1.1072 0.8154 0.782  1.2761 0.2337 0.1807 0.063  1.2118 1.0834 1.2433
#  1.433  1.175  0.9862 1.1181 0.2984 0.9602 0.2053 1.2868 0.809  0.7025]

# %%
z = np.polyfit(data['x'],data['y'], 2)
print(p[0],p[1],p[2])
a=z[0]
b=z[1]
c=z[2]
plt.scatter(data['x'], a*data['x']**2+b*data['x']+c)
# Out:
# 0.060120048402209685 1.6512081616097574 -0.3544471984169096

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Data Set with Y Standard Deviation')
plt.errorbar(data['x'], data['y'], data['y_std'], color = 'red', linestyle='None', marker='^')
plt.scatter(data['x'], a*data['x']**2+b*data['x']+c)
plt.show()
